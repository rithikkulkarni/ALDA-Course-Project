# %% [markdown]
# <a href="https://colab.research.google.com/github/rithikkulkarni/ALDA-Course-Project/blob/main/more_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Importing dataset that has sentiment labels
labeled_df = pd.read_csv('https://raw.githubusercontent.com/rithikkulkarni/ALDA-Course-Project/refs/heads/main/datasets/labeled_stock_tweets.csv')
labeled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80793 entries, 0 to 80792
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          80793 non-null  object
#  1   Tweet         80793 non-null  object
#  2   Stock Name    80793 non-null  object
#  3   Company Name  80793 non-null  object
#  4   Label         80793 non-null  object
# dtypes: object(5)
# memory usage: 3.1+ MB

# %%
labeled_df.head(50)
# Out:
#                          Date  \
# 0   2022-09-29 23:41:16+00:00
# 1   2022-09-29 23:24:43+00:00
# 2   2022-09-29 23:18:08+00:00
# 3   2022-09-29 22:40:07+00:00
# 4   2022-09-29 22:27:05+00:00
# 5   2022-09-29 22:25:53+00:00
# 6   2022-09-29 22:24:22+00:00
# 7   2022-09-29 22:23:54+00:00
# 8   2022-09-29 22:23:28+00:00
# 9   2022-09-29 22:15:01+00:00
# 10  2022-09-29 21:58:00+00:00
# 11  2022-09-29 21:33:05+00:00
# 12  2022-09-29 21:11:30+00:00
# 13  2022-09-29 21:00:25+00:00
# 14  2022-09-29 20:15:41+00:00
# 15  2022-09-29 19:38:29+00:00
# 16  2022-09-29 19:36:59+00:00
# 17  2022-09-29 19:27:54+00:00
# 18  2022-09-29 19:24:50+00:00
# 19  2022-09-29 19:17:48+00:00
# 20  2022-09-29 19:12:32+00:00
# 21  2022-09-29 19:10:37+00:00
# 22  2022-09-29 19:08:03+00:00
# 23  2022-09-29 19:01:22+00:00
# 24  2022-09-29 18:48:36+00:00
# 25  2022-09-29 18:46:07+00:00
# 26  2022-09-29 18:43:55+00:00
# 27  2022-09-29 18:36:51+00:00
# 28  2022-09-29 18:23:20+00:00
# 29  2022-09-29 18:13:24+00:00
# 30  2022-09-29 18:10:14+00:00
# 31  2022-09-29 18:05:22+00:00
# 32  2022-09-29 18:01:17+00:00
# 33  2022-09-29 17:57:57+00:00
# 34  2022-09-29 17:42:24+00:00
# 35  2022-09-29 17:41:43+00:00
# 36  2022-09-29 17:40:44+00:00
# 37  2022-09-29 17:27:23+00:00
# 38  2022-09-29 17:16:23+00:00
# 39  2022-09-29 17:11:40+00:00
# 40  2022-09-29 17:08:22+00:00
# 41  2022-09-29 17:06:40+00:00
# 42  2022-09-29 17:04:23+00:00
# 43  2022-09-29 17:02:49+00:00
# 44  2022-09-29 16:58:56+00:00
# 45  2022-09-29 16:44:48+00:00
# 46  2022-09-29 16:43:49+00:00
# 47  2022-09-29 16:33:44+00:00
# 48  2022-09-29 16:08:18+00:00
# 49  2022-09-29 16:07:31+00:00
#
#                                                 Tweet Stock Name Company Name  \
# 0   Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1   Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2   3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3   @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4   @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.
# 5   @RealDanODowd @Tesla This is you https://t.co/...       TSLA  Tesla, Inc.
# 6   For years @WholeMarsBlog viciously silenced @T...       TSLA  Tesla, Inc.
# 7   $NIO just because I'm down money doesn't mean ...       TSLA  Tesla, Inc.
# 8   50 likes for some $SPY $TSLA charts to study!\...       TSLA  Tesla, Inc.
# 9   @MrJames__321 @KellyRoofing @TeslaSolar @elonm...       TSLA  Tesla, Inc.
# 10  Tomorrow, Tesla, $TSLA, AI day 2 is ongoing.\n...       TSLA  Tesla, Inc.
# 11             Powerwall FTW! https://t.co/GWAaXXCrYv       TSLA  Tesla, Inc.
# 12  $TSLAQ: Tesla’s dead in Europe! Everyone else ...       TSLA  Tesla, Inc.
# 13  The irony is so thick you can cut it with a kn...       TSLA  Tesla, Inc.
# 14  Tesla AI day in 24 hours. Are you ready? $TSLA...       TSLA  Tesla, Inc.
# 15  Picked up some $TSLA shares at $269 https://t....       TSLA  Tesla, Inc.
# 16  2/ Even if @elonmusk loses the $TWTR trial (wo...       TSLA  Tesla, Inc.
# 17  Everyone should keep a long term perspective. ...       TSLA  Tesla, Inc.
# 18  $TSLA Cybertruck can act as a boat according t...       TSLA  Tesla, Inc.
# 19  #GigaBerlinBrandenburg\n@tesla destination cha...       TSLA  Tesla, Inc.
# 20  According to California rules that are now als...       TSLA  Tesla, Inc.
# 21  “New York state plans to adopt California's ru...       TSLA  Tesla, Inc.
# 22  @KellyRoofing @TeslaSolar @elonmusk @Tesla But...       TSLA  Tesla, Inc.
# 23  Tomorrow, Tesla, $TSLA, AI day 2 is ongoing.\n...       TSLA  Tesla, Inc.
# 24  Time for me to wrap up things for next 10 days...       TSLA  Tesla, Inc.
# 25  Today they're shooting the generals.\n$AAPL $T...       TSLA  Tesla, Inc.
# 26  I think i’ll buy some $TSLA today before the c...       TSLA  Tesla, Inc.
# 27  Fuck what you heard, it’s Tesla AI day (part 2...       TSLA  Tesla, Inc.
# 28  This makes my day! #Tesla #hawaii $TSLA https:...       TSLA  Tesla, Inc.
# 29  Even after being down 7% today the PE is 103x....       TSLA  Tesla, Inc.
# 30  Tesla $TSLA Shares Could Rise in Coming Weeks ...       TSLA  Tesla, Inc.
# 31  Meanwhile things continue to go well at Tesla....       TSLA  Tesla, Inc.
# 32  This ugly mean bear market is working its way ...       TSLA  Tesla, Inc.
# 33  $tsla just retested the $798 pre-split level. ...       TSLA  Tesla, Inc.
# 34  No way to sugarcoat $TSLA -6.9% today vs NDX -...       TSLA  Tesla, Inc.
# 35  Friendly reminder to the $TSLA holders: As the...       TSLA  Tesla, Inc.
# 36  $TSLA along a few others the only interesting ...       TSLA  Tesla, Inc.
# 37          @vap1337 @Tesla All I see is a free Tesla       TSLA  Tesla, Inc.
# 38  @TeslaSolar roof stood up to #HurricaneIan wit...       TSLA  Tesla, Inc.
# 39  Rent checks coming in 2 days. \n\nI’ll be plow...       TSLA  Tesla, Inc.
# 40  @TeslaSolar roof stood up to #HurricaneIan wit...       TSLA  Tesla, Inc.
# 41  Investing in the stock market was and never wi...       TSLA  Tesla, Inc.
# 42  Being a $TSLA investor since 2017 has made me ...       TSLA  Tesla, Inc.
# 43  $TSLA now down $60 Pre-split in just a few hou...       TSLA  Tesla, Inc.
# 44  Thank you @Tesla for delivering a car to the w...       TSLA  Tesla, Inc.
# 45  @klwtts @Tesla @elonmusk Hey @elonmusk, Tesla ...       TSLA  Tesla, Inc.
# 46  How do EVs charge after a natural disaster? @t...       TSLA  Tesla, Inc.
# 47  (Reuters) - New York state plans to adopt Cali...       TSLA  Tesla, Inc.
# 48  For those who want to read the anti-Musk view ...       TSLA  Tesla, Inc.
# 49  This thing is never coming to market. $TSLA ht...       TSLA  Tesla, Inc.
#
#        Label
# 0    neutral
# 1    neutral
# 2    neutral
# 3    neutral
# 4   negative
# 5    neutral
# 6    neutral
# 7    neutral
# 8    neutral
# 9   negative
# 10   neutral
# 11   neutral
# 12   neutral
# 13   neutral
# 14   neutral
# 15  positive
# 16   neutral
# 17   neutral
# 18   neutral
# 19   neutral
# 20   neutral
# 21   neutral
# 22   neutral
# 23   neutral
# 24   neutral
# 25   neutral
# 26   neutral
# 27   neutral
# 28   neutral
# 29  negative
# 30  positive
# 31   neutral
# 32   neutral
# 33   neutral
# 34  negative
# 35  negative
# 36  positive
# 37   neutral
# 38   neutral
# 39   neutral
# 40   neutral
# 41   neutral
# 42   neutral
# 43  negative
# 44   neutral
# 45   neutral
# 46   neutral
# 47   neutral
# 48   neutral
# 49   neutral

# %%
balanced_df = labeled_df.copy()

# %%
import pandas as pd
import yfinance as yf
from datetime import timedelta

# Convert date column to datetime objects for easier date manipulation
balanced_df['Date'] = pd.to_datetime(balanced_df['Date']).dt.date

# Drop any previously added columns that might cause merge errors
cols_to_drop = ['stock_label']
balanced_df = balanced_df.drop(columns=[col for col in cols_to_drop if col in balanced_df.columns])

if 'pct_change' in balanced_df.columns:
    balanced_df.drop(columns=['pct_change'], inplace=True)


def get_stock_labels(ticker, dates):
    """
    Download stock data for a given ticker and date range (based on dates from the DataFrame),
    then calculate the next-day percent change and label the movement as 'up', 'down', or 'neutral'.
    Returns a DataFrame with Date, ticker, and stock_label.
    """
    start_date = min(dates) - timedelta(days=1)
    end_date = max(dates) + timedelta(days=2)

    stock_data = yf.download(ticker, start=start_date, end=end_date)
    print(f"Downloading data for {ticker}, initial columns:", stock_data.columns)

    # Flatten columns if they are a MultiIndex
    if isinstance(stock_data.columns, pd.MultiIndex):
        stock_data.columns = stock_data.columns.get_level_values(0)

    # Use 'Close' or 'Adj Close' from yfinance download
    if 'Close' not in stock_data.columns:
        if 'Adj Close' in stock_data.columns:
            stock_data['Close'] = stock_data['Adj Close']
            print("Using 'Adj Close' as 'Close'")
        else:
            raise KeyError("Neither 'Close' nor 'Adj Close' found in the stock data.")

    # Convert index to date objects
    stock_data.index = pd.to_datetime(stock_data.index).date

    # Create 'next_close' column by shifting the 'Close' column by -1 (next day)
    stock_data['next_close'] = stock_data['Close'].shift(-1)
    # Drop rows where next_close is NaN (usually the last row)
    stock_data = stock_data.dropna(subset=['next_close'])

    # Calculate percentage change between today's close and next day's close
    stock_data['pct_change'] = (stock_data['next_close'] - stock_data['Close']) / stock_data['Close']

    # Label the movement: change > 1.5% is 'up', change < -1.5% is 'down', else 'neutral'
    def label_movement(pct):
      if pct > 0:
        return 1
      else:
        return -1
        # if pct > 0.015:
        #     return 1
        # elif pct < -0.015:
        #     return -1
        # else:
        #     return 0

    stock_data['stock_label'] = stock_data['pct_change'].apply(label_movement)
    stock_data['pct_change'] = (stock_data['next_close'] - stock_data['Close']) / stock_data['Close'] * 100

    # Create a DataFrame with Date, ticker, and stock_label.
    stock_labels = stock_data[['stock_label', 'pct_change']].copy()
    stock_labels = stock_labels.reset_index().rename(columns={'index': 'Date'})
    stock_labels['Stock Name'] = ticker
    return stock_labels

# List to hold the labeled subsets for each ticker.
labeled_dfs = []

# Process each unique ticker found in the DataFrame.
for t in balanced_df['Stock Name'].unique():
    subset = balanced_df[balanced_df['Stock Name'] == t].copy()
    dates = subset['Date']
    print(f"Processing ticker: {t}, with date range {min(dates)} to {max(dates)}")

    # Get the stock labels for this ticker
    stock_labels = get_stock_labels(t, dates)

    # Merge on both 'Date' and 'Stock Name'
    merged = pd.merge(subset, stock_labels, on=['Date', 'Stock Name'], how='inner')
    labeled_dfs.append(merged)

# Combine all labeled subsets into one DataFrame
balanced_df = pd.concat(labeled_dfs, ignore_index=True)
print("Labeled DataFrame head:\n", balanced_df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Processing ticker: TSLA, with date range 2021-09-30 to 2022-09-29
# Downloading data for TSLA, initial columns: MultiIndex([( 'Close', 'TSLA'),
#             (  'High', 'TSLA'),
#             (   'Low', 'TSLA'),
#             (  'Open', 'TSLA'),
#             ('Volume', 'TSLA')],
#            names=['Price', 'Ticker'])
# Processing ticker: MSFT, with date range 2021-09-30 to 2022-09-29
# Downloading data for MSFT, initial columns: MultiIndex([( 'Close', 'MSFT'),
#             (  'High', 'MSFT'),
#             (   'Low', 'MSFT'),
#             (  'Open', 'MSFT'),
#             ('Volume', 'MSFT')],
#            names=['Price', 'Ticker'])
# Processing ticker: PG, with date range 2021-09-30 to 2022-09-29
# Downloading data for PG, initial columns: MultiIndex([( 'Close', 'PG'),
#             (  'High', 'PG'),
#             (   'Low', 'PG'),
#             (  'Open', 'PG'),
#             ('Volume', 'PG')],
#            names=['Price', 'Ticker'])
# Processing ticker: META, with date range 2021-09-30 to 2022-09-29
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading data for META, initial columns: MultiIndex([( 'Close', 'META'),
#             (  'High', 'META'),
#             (   'Low', 'META'),
#             (  'Open', 'META'),
#             ('Volume', 'META')],
#            names=['Price', 'Ticker'])
# Processing ticker: AMZN, with date range 2021-09-30 to 2022-09-29
# Downloading data for AMZN, initial columns: MultiIndex([( 'Close', 'AMZN'),
#             (  'High', 'AMZN'),
#             (   'Low', 'AMZN'),
#             (  'Open', 'AMZN'),
#             ('Volume', 'AMZN')],
#            names=['Price', 'Ticker'])
# Processing ticker: GOOG, with date range 2021-09-30 to 2022-09-29
# Downloading data for GOOG, initial columns: MultiIndex([( 'Close', 'GOOG'),
#             (  'High', 'GOOG'),
#             (   'Low', 'GOOG'),
#             (  'Open', 'GOOG'),
#             ('Volume', 'GOOG')],
#            names=['Price', 'Ticker'])
# Processing ticker: AMD, with date range 2021-09-30 to 2022-09-29
# Downloading data for AMD, initial columns: MultiIndex([( 'Close', 'AMD'),
#             (  'High', 'AMD'),
#             (   'Low', 'AMD'),
#             (  'Open', 'AMD'),
#             ('Volume', 'AMD')],
#            names=['Price', 'Ticker'])
# Processing ticker: AAPL, with date range 2021-09-30 to 2022-09-29
# Downloading data for AAPL, initial columns: MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Processing ticker: NFLX, with date range 2021-09-30 to 2022-09-29
# Downloading data for NFLX, initial columns: MultiIndex([( 'Close', 'NFLX'),
#             (  'High', 'NFLX'),
#             (   'Low', 'NFLX'),
#             (  'Open', 'NFLX'),
#             ('Volume', 'NFLX')],
#            names=['Price', 'Ticker'])
# Processing ticker: TSM, with date range 2021-09-30 to 2022-09-29
# Downloading data for TSM, initial columns: MultiIndex([( 'Close', 'TSM'),
#             (  'High', 'TSM'),
#             (   'Low', 'TSM'),
#             (  'Open', 'TSM'),
#             ('Volume', 'TSM')],
#            names=['Price', 'Ticker'])
# Processing ticker: KO, with date range 2021-10-02 to 2022-09-29
# Downloading data for KO, initial columns: MultiIndex([( 'Close', 'KO'),
#             (  'High', 'KO'),
#             (   'Low', 'KO'),
#             (  'Open', 'KO'),
#             ('Volume', 'KO')],
#            names=['Price', 'Ticker'])
# Processing ticker: F, with date range 2021-10-07 to 2022-09-08
# Downloading data for F, initial columns: MultiIndex([( 'Close', 'F'),
#             (  'High', 'F'),
#             (   'Low', 'F'),
#             (  'Open', 'F'),
#             ('Volume', 'F')],
#            names=['Price', 'Ticker'])
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Processing ticker: COST, with date range 2021-10-05 to 2022-09-29
# Downloading data for COST, initial columns: MultiIndex([( 'Close', 'COST'),
#             (  'High', 'COST'),
#             (   'Low', 'COST'),
#             (  'Open', 'COST'),
#             ('Volume', 'COST')],
#            names=['Price', 'Ticker'])
# Processing ticker: DIS, with date range 2021-09-30 to 2022-09-29
# Downloading data for DIS, initial columns: MultiIndex([( 'Close', 'DIS'),
#             (  'High', 'DIS'),
#             (   'Low', 'DIS'),
#             (  'Open', 'DIS'),
#             ('Volume', 'DIS')],
#            names=['Price', 'Ticker'])
# Processing ticker: VZ, with date range 2021-10-12 to 2022-09-28
# Downloading data for VZ, initial columns: MultiIndex([( 'Close', 'VZ'),
#             (  'High', 'VZ'),
#             (   'Low', 'VZ'),
#             (  'Open', 'VZ'),
#             ('Volume', 'VZ')],
#            names=['Price', 'Ticker'])
# Processing ticker: CRM, with date range 2021-10-01 to 2022-09-28
# Downloading data for CRM, initial columns: MultiIndex([( 'Close', 'CRM'),
#             (  'High', 'CRM'),
#             (   'Low', 'CRM'),
#             (  'Open', 'CRM'),
#             ('Volume', 'CRM')],
#            names=['Price', 'Ticker'])
# Processing ticker: INTC, with date range 2021-10-07 to 2022-09-29
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading data for INTC, initial columns: MultiIndex([( 'Close', 'INTC'),
#             (  'High', 'INTC'),
#             (   'Low', 'INTC'),
#             (  'Open', 'INTC'),
#             ('Volume', 'INTC')],
#            names=['Price', 'Ticker'])
# Processing ticker: BA, with date range 2021-10-03 to 2022-09-26
# Downloading data for BA, initial columns: MultiIndex([( 'Close', 'BA'),
#             (  'High', 'BA'),
#             (   'Low', 'BA'),
#             (  'Open', 'BA'),
#             ('Volume', 'BA')],
#            names=['Price', 'Ticker'])
# Processing ticker: BX, with date range 2021-10-07 to 2022-09-27
# Downloading data for BX, initial columns: MultiIndex([( 'Close', 'BX'),
#             (  'High', 'BX'),
#             (   'Low', 'BX'),
#             (  'Open', 'BX'),
#             ('Volume', 'BX')],
#            names=['Price', 'Ticker'])
# Processing ticker: NOC, with date range 2021-10-07 to 2022-09-08
# Downloading data for NOC, initial columns: MultiIndex([( 'Close', 'NOC'),
#             (  'High', 'NOC'),
#             (   'Low', 'NOC'),
#             (  'Open', 'NOC'),
#             ('Volume', 'NOC')],
#            names=['Price', 'Ticker'])
# Processing ticker: PYPL, with date range 2021-10-03 to 2022-09-29
# Downloading data for PYPL, initial columns: MultiIndex([( 'Close', 'PYPL'),
#             (  'High', 'PYPL'),
#             (   'Low', 'PYPL'),
#             (  'Open', 'PYPL'),
#             ('Volume', 'PYPL')],
#            names=['Price', 'Ticker'])
# Processing ticker: ENPH, with date range 2021-10-02 to 2022-09-28
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading data for ENPH, initial columns: MultiIndex([( 'Close', 'ENPH'),
#             (  'High', 'ENPH'),
#             (   'Low', 'ENPH'),
#             (  'Open', 'ENPH'),
#             ('Volume', 'ENPH')],
#            names=['Price', 'Ticker'])
# Processing ticker: NIO, with date range 2021-09-30 to 2022-09-29
# Downloading data for NIO, initial columns: MultiIndex([( 'Close', 'NIO'),
#             (  'High', 'NIO'),
#             (   'Low', 'NIO'),
#             (  'Open', 'NIO'),
#             ('Volume', 'NIO')],
#            names=['Price', 'Ticker'])
# Processing ticker: ZS, with date range 2021-10-01 to 2022-09-29
# Downloading data for ZS, initial columns: MultiIndex([( 'Close', 'ZS'),
#             (  'High', 'ZS'),
#             (   'Low', 'ZS'),
#             (  'Open', 'ZS'),
#             ('Volume', 'ZS')],
#            names=['Price', 'Ticker'])
# Processing ticker: XPEV, with date range 2021-09-30 to 2022-09-26
# Downloading data for XPEV, initial columns: MultiIndex([( 'Close', 'XPEV'),
#             (  'High', 'XPEV'),
#             (   'Low', 'XPEV'),
#             (  'Open', 'XPEV'),
#             ('Volume', 'XPEV')],
#            names=['Price', 'Ticker'])
# Labeled DataFrame head:
#           Date                                              Tweet Stock Name  \
# 0  2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1  2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2  2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3  2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4  2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
#
#   Company Name     Label  stock_label  pct_change
# 0  Tesla, Inc.   neutral           -1    -1.10361
# 1  Tesla, Inc.   neutral           -1    -1.10361
# 2  Tesla, Inc.   neutral           -1    -1.10361
# 3  Tesla, Inc.   neutral           -1    -1.10361
# 4  Tesla, Inc.  negative           -1    -1.10361

# %%
# Sanity checks for new stock labels
print(balanced_df.stock_label.value_counts())
print(balanced_df.describe())
# Out:
# stock_label
# -1    32716
#  1    30960
# Name: count, dtype: int64
#         stock_label    pct_change
# count  63676.000000  63676.000000
# mean      -0.027577     -0.200207
# std        0.999628      4.585244
# min       -1.000000    -35.116603
# 25%       -1.000000     -2.027453
# 50%       -1.000000     -0.082298
# 75%        1.000000      1.823662
# max        1.000000     25.586066

# %%
# Mapping sentiment values to numerical (-1,0,1) to make life easier for our models
def sentiment_to_number(sentiment):
    mapping = {
        "positive": 1,
        "neutral": 0,
        "negative": -1
    }
    # Normalize the input to lowercase to ensure consistency
    return mapping.get(sentiment.lower(), 0)
balanced_df['Label'] = balanced_df['Label'].apply(sentiment_to_number)
balanced_df.head(25)
# Out:
#           Date                                              Tweet Stock Name  \
# 0   2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1   2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2   2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3   2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4   2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
# 5   2022-09-29  @RealDanODowd @Tesla This is you https://t.co/...       TSLA
# 6   2022-09-29  For years @WholeMarsBlog viciously silenced @T...       TSLA
# 7   2022-09-29  $NIO just because I'm down money doesn't mean ...       TSLA
# 8   2022-09-29  50 likes for some $SPY $TSLA charts to study!\...       TSLA
# 9   2022-09-29  @MrJames__321 @KellyRoofing @TeslaSolar @elonm...       TSLA
# 10  2022-09-29  Tomorrow, Tesla, $TSLA, AI day 2 is ongoing.\n...       TSLA
# 11  2022-09-29             Powerwall FTW! https://t.co/GWAaXXCrYv       TSLA
# 12  2022-09-29  $TSLAQ: Tesla’s dead in Europe! Everyone else ...       TSLA
# 13  2022-09-29  The irony is so thick you can cut it with a kn...       TSLA
# 14  2022-09-29  Tesla AI day in 24 hours. Are you ready? $TSLA...       TSLA
# 15  2022-09-29  Picked up some $TSLA shares at $269 https://t....       TSLA
# 16  2022-09-29  2/ Even if @elonmusk loses the $TWTR trial (wo...       TSLA
# 17  2022-09-29  Everyone should keep a long term perspective. ...       TSLA
# 18  2022-09-29  $TSLA Cybertruck can act as a boat according t...       TSLA
# 19  2022-09-29  #GigaBerlinBrandenburg\n@tesla destination cha...       TSLA
# 20  2022-09-29  According to California rules that are now als...       TSLA
# 21  2022-09-29  “New York state plans to adopt California's ru...       TSLA
# 22  2022-09-29  @KellyRoofing @TeslaSolar @elonmusk @Tesla But...       TSLA
# 23  2022-09-29  Tomorrow, Tesla, $TSLA, AI day 2 is ongoing.\n...       TSLA
# 24  2022-09-29  Time for me to wrap up things for next 10 days...       TSLA
#
#    Company Name  Label  stock_label  pct_change
# 0   Tesla, Inc.      0           -1    -1.10361
# 1   Tesla, Inc.      0           -1    -1.10361
# 2   Tesla, Inc.      0           -1    -1.10361
# 3   Tesla, Inc.      0           -1    -1.10361
# 4   Tesla, Inc.     -1           -1    -1.10361
# 5   Tesla, Inc.      0           -1    -1.10361
# 6   Tesla, Inc.      0           -1    -1.10361
# 7   Tesla, Inc.      0           -1    -1.10361
# 8   Tesla, Inc.      0           -1    -1.10361
# 9   Tesla, Inc.     -1           -1    -1.10361
# 10  Tesla, Inc.      0           -1    -1.10361
# 11  Tesla, Inc.      0           -1    -1.10361
# 12  Tesla, Inc.      0           -1    -1.10361
# 13  Tesla, Inc.      0           -1    -1.10361
# 14  Tesla, Inc.      0           -1    -1.10361
# 15  Tesla, Inc.      1           -1    -1.10361
# 16  Tesla, Inc.      0           -1    -1.10361
# 17  Tesla, Inc.      0           -1    -1.10361
# 18  Tesla, Inc.      0           -1    -1.10361
# 19  Tesla, Inc.      0           -1    -1.10361
# 20  Tesla, Inc.      0           -1    -1.10361
# 21  Tesla, Inc.      0           -1    -1.10361
# 22  Tesla, Inc.      0           -1    -1.10361
# 23  Tesla, Inc.      0           -1    -1.10361
# 24  Tesla, Inc.      0           -1    -1.10361

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from datetime import timedelta
from scipy import stats

# This cell creates a graph that has sentiment scores as the shaded background color along with the stock price movement. We also
# shifted the sentiment scores back 1 day so we could see their affects 24 hours after

# Example input
ticker = "TSLA"
days_back = 120

# Filter tweets by company and recent "days_back" days
df = balanced_df.copy()
df['Date'] = pd.to_datetime(df['Date'])

end_date = df['Date'].max()
start_date = end_date - timedelta(days=days_back)

filtered_df = df[(df['Stock Name'].str.lower() == ticker.lower()) &
                 (df['Date'] >= start_date) &
                 (df['Date'] <= end_date)]

# Group sentiment by date
daily_sentiment = filtered_df.groupby(filtered_df['Date'].dt.date)['Label'].agg(
    lambda x: x.mode().iloc[0] if not x.mode().empty else 'neutral'
)

# Shifting sentiment to affect 24 hours after
daily_sentiment.index = pd.to_datetime(daily_sentiment.index) - pd.Timedelta(days=1)
daily_sentiment.index = daily_sentiment.index.date

# Fetch stock data from yfinance
stock_data = yf.download(ticker, start=start_date.strftime('%Y-%m-%d'),
                         end=(end_date + timedelta(days=1)).strftime('%Y-%m-%d'),
                         progress=False)

# Plot stock closing prices
fig, ax = plt.subplots(figsize=(12, 6))
stock_data['Close'].plot(ax=ax, color='black', linewidth=2)
ax.set_ylabel("Stock Price (Close)")
ax.set_xlabel("Date")

# 6. Shade background per day
for i, day in enumerate(stock_data.index.date):
    sentiment = daily_sentiment.get(day, 0)
    if sentiment > 0:
        color = 'green'
    elif sentiment < 0:
        color = 'red'
    else:
        color = 'orange'

    ax.axvspan(day, day + timedelta(days=1), color=color, alpha=0.2)

plt.tight_layout()
plt.show()
filtered_df.head()
# Out:
#         Date                                              Tweet Stock Name  \
# 0 2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1 2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2 2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3 2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4 2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
#
#   Company Name  Label  stock_label  pct_change
# 0  Tesla, Inc.      0           -1    -1.10361
# 1  Tesla, Inc.      0           -1    -1.10361
# 2  Tesla, Inc.      0           -1    -1.10361
# 3  Tesla, Inc.      0           -1    -1.10361
# 4  Tesla, Inc.     -1           -1    -1.10361

# %%
print(balanced_df.head(5))
print(df.head(5))
# Out:
#          Date                                              Tweet Stock Name  \
# 0  2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1  2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2  2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3  2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4  2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
#
#   Company Name  Label  stock_label  pct_change
# 0  Tesla, Inc.      0           -1    -1.10361
# 1  Tesla, Inc.      0           -1    -1.10361
# 2  Tesla, Inc.      0           -1    -1.10361
# 3  Tesla, Inc.      0           -1    -1.10361
# 4  Tesla, Inc.     -1           -1    -1.10361
#         Date                                              Tweet Stock Name  \
# 0 2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1 2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2 2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3 2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4 2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
#
#   Company Name  Label  stock_label  pct_change
# 0  Tesla, Inc.      0           -1    -1.10361
# 1  Tesla, Inc.      0           -1    -1.10361
# 2  Tesla, Inc.      0           -1    -1.10361
# 3  Tesla, Inc.      0           -1    -1.10361
# 4  Tesla, Inc.     -1           -1    -1.10361

# %%
import yfinance as yf
import pandas as pd
from datetime import timedelta

# NUM HISTORICAL DAYS
n = 30

# Ensure Date column is in datetime format
balanced_df['Date'] = pd.to_datetime(balanced_df['Date'])

# Get the unique ticker symbols from the DataFrame
tickers = balanced_df['Stock Name'].unique()

# Create a dictionary to store historical data for each ticker
price_data = {}

for ticker in tickers:
    # Get all dates for this ticker
    ticker_dates = pd.to_datetime(balanced_df[balanced_df['Stock Name'] == ticker]['Date'])
    # Define a start date for downloading data. Adjust timedelta as needed (e.g., if you need a 90-day window, subtract 120 days)
    start_date = (ticker_dates.min() - timedelta(days=n)).strftime('%Y-%m-%d')
    # Define an end date slightly beyond the latest date in your data to ensure coverage
    end_date = (ticker_dates.max() + timedelta(days=1)).strftime('%Y-%m-%d')

    # Download historical data for the ticker
    df_ticker = yf.download(ticker, start=start_date, end=end_date, progress=False)
    price_data[ticker] = df_ticker

def get_features(row):
    ticker = row['Stock Name']
    date = row['Date']

    # Get the pre-downloaded historical data for this ticker
    df = price_data.get(ticker)

    if df is None or df.empty:
        return pd.Series([None, None, None, None])

    # Filter data for dates strictly before the given date
    df_filtered = df[df.index < date]

    if len(df_filtered) < 3:
        return pd.Series([None, None, None, None])

    # Get the last three available closing prices
    one_day_price = df_filtered['Close'].iloc[-1]
    two_day_price = df_filtered['Close'].iloc[-2]
    three_day_price = df_filtered['Close'].iloc[-3]

    # Calculate the average closing price over the past n days (adjust timedelta if needed for our window)
    df_window = df_filtered[df_filtered.index >= (date - timedelta(days=n))]
    historical_price = df_window['Close'].mean() if not df_window.empty else None

    return pd.Series([one_day_price, two_day_price, three_day_price, historical_price])

# Apply the get_features function to each row
balanced_df[['one_day_price', 'two_day_price', 'three_day_price', 'historical_price']] = balanced_df.apply(get_features, axis=1)

# %%
### Converting the extracted historical price features into just their floating point values (converted to nearest dollars.cents)

def extract_single_value(x):
    """
    If x is a Pandas Series with one element, extract and return that element.
    Otherwise, return x unchanged.
    """
    if isinstance(x, pd.Series) and x.size == 1:
        return x.iloc[0]
    return x

# List the price feature columns that need cleaning
price_columns = ['one_day_price', 'two_day_price', 'three_day_price', 'historical_price']

# Apply the function to just those columns using applymap
balanced_df[price_columns] = balanced_df[price_columns].applymap(extract_single_value)

# Optionally, round the values to two decimal places if needed:
balanced_df[price_columns] = balanced_df[price_columns].astype(float).round(2)
# Out:
# <ipython-input-36-5095b1dbcdb5>:16: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   balanced_df[price_columns] = balanced_df[price_columns].applymap(extract_single_value)

# %%
print(balanced_df.head(1000)['one_day_price'][999])
# Out:
# 292.13

# %%
balanced_df.head(100)
# Out:
#          Date                                              Tweet Stock Name  \
# 0  2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1  2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2  2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3  2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4  2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
# ..        ...                                                ...        ...
# 95 2022-09-29  Next year the city streets are going to be ver...       TSLA
# 96 2022-09-29  Tesla Full Self-Driving Beta is trained on dat...       TSLA
# 97 2022-09-29  “The code you will write will at term run in m...       TSLA
# 98 2022-09-29  FSD SAVES LIVES. $TSLA \n\nhttps://t.co/4p8wnl...       TSLA
# 99 2022-09-29  "If you say, 'OK, who is Tesla hurting the mos...       TSLA
#
#    Company Name  Label  stock_label  pct_change  one_day_price  two_day_price  \
# 0   Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 1   Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 2   Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 3   Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 4   Tesla, Inc.     -1           -1    -1.10361         287.81         282.94
# ..          ...    ...          ...         ...            ...            ...
# 95  Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 96  Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 97  Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 98  Tesla, Inc.      0           -1    -1.10361         287.81         282.94
# 99  Tesla, Inc.      0           -1    -1.10361         287.81         282.94
#
#     three_day_price  historical_price
# 0            276.01            289.68
# 1            276.01            289.68
# 2            276.01            289.68
# 3            276.01            289.68
# 4            276.01            289.68
# ..              ...               ...
# 95           276.01            289.68
# 96           276.01            289.68
# 97           276.01            289.68
# 98           276.01            289.68
# 99           276.01            289.68
#
# [100 rows x 11 columns]

# %%
balanced_df.to_csv('labeled_stock_tweets_with_historical_prices.csv', index=False)

# %%
import pandas as pd
from statistics import mode

# Group by Date and Stock Name
grouped = balanced_df.groupby(['Date', 'Stock Name'])

# Define aggregation for each column
agg_dict = {
    'Label': mode,
    'stock_label': 'first',
    'pct_change': 'first',
    'one_day_price': 'first',
    'two_day_price': 'first',
    'three_day_price': 'first',
    'historical_price': 'first'
}

# Perform the aggregation
filtered_df = grouped.agg(agg_dict).reset_index()
filtered_df['sentiment'] = filtered_df['Label']
filtered_df.rename(columns={'Label': 'sentiment', 'stock_label': 'stock_performance'}, inplace=True)
filtered_df.to_csv('filtered_stocks.csv', index=False)
filtered_df.head(5)
# Out:
#         Date Stock Name  sentiment  stock_performance  pct_change  \
# 0 2021-09-30       AAPL          0                  1    0.812706
# 1 2021-09-30        AMD          0                 -1   -0.437322
# 2 2021-09-30       AMZN          0                 -1   -0.054188
# 3 2021-09-30        DIS          0                  1    4.043260
# 4 2021-09-30       GOOG          0                  1    2.398960
#
#    one_day_price  two_day_price  three_day_price  historical_price  sentiment
# 0         140.17         139.27           142.66            146.03          0
# 1         100.35         101.52           108.16            105.88          0
# 2         165.06         165.80           170.29            171.80          0
# 3         170.57         172.39           176.08            178.13          0
# 4         133.89         135.54           140.83            141.79          0

# %%
aapl_tweets = balanced_df[
    (balanced_df['Stock Name'] == 'AAPL') &
    (pd.to_datetime(balanced_df['Date']).dt.date == pd.to_datetime('2021-09-30').date())
]

# Display the results
aapl_tweets[['Date', 'Stock Name', 'Tweet']]
# Out:
#             Date Stock Name                                              Tweet
# 49338 2021-09-30       AAPL                       I need 1,000 shares of $AAPL
# 49339 2021-09-30       AAPL  Returns over the last 10 Years:\n\nBitcoin $BT...
# 49340 2021-09-30       AAPL  All about this trendline now on $AAPL, continu...
# 49341 2021-09-30       AAPL  This thread is just a broad overview of the ba...
# 49342 2021-09-30       AAPL  In 2020, Tim Cook, CEO of $AAPL, earned $265,0...
# 49343 2021-09-30       AAPL  The media is really pushing hard for their big...
# 49344 2021-09-30       AAPL  I bought my first $AAPL stock in 2010. \n\nSin...
